# %% [raw]
# Step 1:Understand the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/User/PyCharmMiscProject/python/DataSets/datalab_export_2026-06-29 14_39_03.csv')
df
