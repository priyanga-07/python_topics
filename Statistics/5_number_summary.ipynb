# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
y=(-13,-12,-5,-6,3,4,5,6,7,7,8,10,10,11,55)
y1=np.array(y)
y1
df=pd.DataFrame(y1)
print(df)
mim=df.min()
print('f:minimum value:', mim)
q1=df.quantile(0.25)
print('q1:', q1)
q2=df.quantile(0.50)
print('q2:', q2)
q3=df.quantile(0.75)
print('q3:', q3)
max=df.max()
print('max:', max)
iqr=q3-q1
print('iqr:', iqr)
lf=q1-1.5*iqr
print('lf:', lf)
hf=q1+1.5*iqr
print('hf:', hf)
print(df.describe())
plt.figure(figsize=(6,4))
plt.boxplot(y)
plt.title("Box Plot")
plt.show()

# sns.barplot(df)
# plt.show()
# Out:
#      0
# 0  -13
# 1  -12
# 2   -5
# 3   -6
# 4    3
# 5    4
# 6    5
# 7    6
# 8    7
# 9    7
# 10   8
# 11  10
# 12  10
# 13  11
# 14  55
# f:minimum value: 0   -13
# dtype: int64
# q1: 0   -1.0
# Name: 0.25, dtype: float64
# q2: 0    6.0
# Name: 0.5, dtype: float64
# q3: 0    9.0
# Name: 0.75, dtype: float64
# max: 0    55
# dtype: int64
# iqr: 0    10.0
# dtype: float64
# lf: 0   -16.0
# dtype: float64
# hf: 0    14.0
# dtype: float64
#                0
# count  15.000000
# mean    6.000000
# std    15.647912
# min   -13.000000
# 25%    -1.000000
# 50%     6.000000
# 75%     9.000000
# max    55.000000

# %%
df.skew()
df.hist(bins=20)
plt.figure(figsize=(6,4))
plt.show()
